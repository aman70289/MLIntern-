# %% [markdown]
# <a href="https://colab.research.google.com/github/aman70289/MLIntern-/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Supervised Learning Model Comparison
#
# This notebook demonstrates the implementation, training, and evaluation of several supervised learning algorithms using the Iris dataset.

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# Load the Iris dataset
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.Series(iris.target)

print("Features (X) head:")
display(X.head())

print("\nTarget (y) head:")
display(y.head())

print(f"\nDataset shape: X={X.shape}, y={y.shape}")
# Out:
# Features (X) head:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# Target (y) head:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64
# Dataset shape: X=(150, 4), y=(150,)

# %% [markdown]
# ### Data Splitting
#
# Now, let's split the dataset into training and testing sets. This is crucial to evaluate model performance on unseen data.

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (105, 4)
# X_test shape: (45, 4)
# y_train shape: (105,)
# y_test shape: (45,)

# %% [markdown]
# ### Model Training and Prediction
#
# We will now train Logistic Regression and Decision Tree models and make predictions on the test set. We'll start with Logistic Regression.

# %%
from sklearn.linear_model import LogisticRegression

# Initialize and train the Logistic Regression model
logistic_model = LogisticRegression(max_iter=200, random_state=42)
logistic_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred_logistic = logistic_model.predict(X_test)

print("Logistic Regression Model trained successfully.")
print("First 5 predictions from Logistic Regression:", y_pred_logistic[:5])
# Out:
# Logistic Regression Model trained successfully.
# First 5 predictions from Logistic Regression: [2 1 1 1 2]

# %% [markdown]
# Next, let's train a Decision Tree Classifier.

# %%
from sklearn.tree import DecisionTreeClassifier

# Initialize and train the Decision Tree model
decision_tree_model = DecisionTreeClassifier(random_state=42)
decision_tree_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred_decision_tree = decision_tree_model.predict(X_test)

print("Decision Tree Model trained successfully.")
print("First 5 predictions from Decision Tree:", y_pred_decision_tree[:5])
# Out:
# Decision Tree Model trained successfully.
# First 5 predictions from Decision Tree: [2 1 2 2 2]

# %% [markdown]
# ### Model Evaluation
#
# We will now evaluate the performance of both Logistic Regression and Decision Tree models using various metrics.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# Evaluate Logistic Regression
accuracy_logistic = accuracy_score(y_test, y_pred_logistic)
precision_logistic = precision_score(y_test, y_pred_logistic, average='weighted')
recall_logistic = recall_score(y_test, y_pred_logistic, average='weighted')
f1_logistic = f1_score(y_test, y_pred_logistic, average='weighted')

print("--- Logistic Regression Evaluation ---")
print(f"Accuracy: {accuracy_logistic:.4f}")
print(f"Precision: {precision_logistic:.4f}")
print(f"Recall: {recall_logistic:.4f}")
print(f"F1-Score: {f1_logistic:.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred_logistic))
# Out:
# --- Logistic Regression Evaluation ---
# Accuracy: 0.9333
# Precision: 0.9345
# Recall: 0.9333
# F1-Score: 0.9333
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       0.88      0.93      0.90        15
#            2       0.93      0.87      0.90        15
#
#     accuracy                           0.93        45
#    macro avg       0.93      0.93      0.93        45
# weighted avg       0.93      0.93      0.93        45

# %%
# Evaluate Decision Tree
accuracy_decision_tree = accuracy_score(y_test, y_pred_decision_tree)
precision_decision_tree = precision_score(y_test, y_pred_decision_tree, average='weighted')
recall_decision_tree = recall_score(y_test, y_pred_decision_tree, average='weighted')
f1_decision_tree = f1_score(y_test, y_pred_decision_tree, average='weighted')

print("\n--- Decision Tree Evaluation ---")
print(f"Accuracy: {accuracy_decision_tree:.4f}")
print(f"Precision: {precision_decision_tree:.4f}")
print(f"Recall: {recall_decision_tree:.4f}")
print(f"F1-Score: {f1_decision_tree:.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred_decision_tree))
# Out:
# --- Decision Tree Evaluation ---
# Accuracy: 0.9333
# Precision: 0.9444
# Recall: 0.9333
# F1-Score: 0.9327
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      0.80      0.89        15
#            2       0.83      1.00      0.91        15
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.93      0.93        45
# weighted avg       0.94      0.93      0.93        45

# %% [markdown]
# ### Consolidated Model Performance Comparison

# %%
import pandas as pd

performance_data = {
    'Model': ['Logistic Regression', 'Decision Tree', 'K-Nearest Neighbors', 'Random Forest'],
    'Accuracy': [accuracy_logistic, accuracy_decision_tree, accuracy_knn, accuracy_random_forest],
    'Precision (Weighted)': [precision_logistic, precision_decision_tree, precision_knn, precision_random_forest],
    'Recall (Weighted)': [recall_logistic, recall_decision_tree, recall_knn, recall_random_forest],
    'F1-Score (Weighted)': [f1_logistic, f1_decision_tree, f1_knn, f1_random_forest]
}

performance_df = pd.DataFrame(performance_data)
performance_df.set_index('Model', inplace=True)

print("\n--- Model Performance Summary ---")
display(performance_df.round(4))

print("\nBased on the Iris dataset, most models performed quite well, achieving high accuracy and F1-scores. K-Nearest Neighbors shows the highest accuracy, precision, recall, and F1-score, indicating a robust performance overall. Random Forest also performs strongly.")
# Out:
# --- Model Performance Summary ---
#                      Accuracy  Precision (Weighted)  Recall (Weighted)  \
# Model
# Logistic Regression    0.9333                0.9345             0.9333
# Decision Tree          0.9333                0.9444             0.9333
# K-Nearest Neighbors    0.9778                0.9792             0.9778
# Random Forest          0.8889                0.8981             0.8889
#
#                      F1-Score (Weighted)
# Model
# Logistic Regression               0.9333
# Decision Tree                     0.9327
# K-Nearest Neighbors               0.9778
# Random Forest                     0.8878
# Based on the Iris dataset, most models performed quite well, achieving high accuracy and F1-scores. K-Nearest Neighbors shows the highest accuracy, precision, recall, and F1-score, indicating a robust performance overall. Random Forest also performs strongly.

# %% [markdown]
# ### Training and Evaluating K-Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

# Initialize and train the K-Nearest Neighbors model
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred_knn = knn_model.predict(X_test)

print("K-Nearest Neighbors Model trained successfully.")
print("First 5 predictions from KNN:", y_pred_knn[:5])

# Evaluate KNN
accuracy_knn = accuracy_score(y_test, y_pred_knn)
precision_knn = precision_score(y_test, y_pred_knn, average='weighted')
recall_knn = recall_score(y_test, y_pred_knn, average='weighted')
f1_knn = f1_score(y_test, y_pred_knn, average='weighted')

print("\n--- K-Nearest Neighbors Evaluation ---")
print(f"Accuracy: {accuracy_knn:.4f}")
print(f"Precision: {precision_knn:.4f}")
print(f"Recall: {recall_knn:.4f}")
print(f"F1-Score: {f1_knn:.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred_knn))
# Out:
# K-Nearest Neighbors Model trained successfully.
# First 5 predictions from KNN: [2 1 2 1 2]
#
# --- K-Nearest Neighbors Evaluation ---
# Accuracy: 0.9778
# Precision: 0.9792
# Recall: 0.9778
# F1-Score: 0.9778
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       0.94      1.00      0.97        15
#            2       1.00      0.93      0.97        15
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# ### Training and Evaluating Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize and train the Random Forest model
random_forest_model = RandomForestClassifier(n_estimators=100, random_state=42)
random_forest_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred_random_forest = random_forest_model.predict(X_test)

print("Random Forest Model trained successfully.")
print("First 5 predictions from Random Forest:", y_pred_random_forest[:5])

# Evaluate Random Forest
accuracy_random_forest = accuracy_score(y_test, y_pred_random_forest)
precision_random_forest = precision_score(y_test, y_pred_random_forest, average='weighted')
recall_random_forest = recall_score(y_test, y_pred_random_forest, average='weighted')
f1_random_forest = f1_score(y_test, y_pred_random_forest, average='weighted')

print("\n--- Random Forest Evaluation ---")
print(f"Accuracy: {accuracy_random_forest:.4f}")
print(f"Precision: {precision_random_forest:.4f}")
print(f"Recall: {recall_random_forest:.4f}")
print(f"F1-Score: {f1_random_forest:.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred_random_forest))
# Out:
# Random Forest Model trained successfully.
# First 5 predictions from Random Forest: [2 1 1 1 2]
#
# --- Random Forest Evaluation ---
# Accuracy: 0.8889
# Precision: 0.8981
# Recall: 0.8889
# F1-Score: 0.8878
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       0.78      0.93      0.85        15
#            2       0.92      0.73      0.81        15
#
#     accuracy                           0.89        45
#    macro avg       0.90      0.89      0.89        45
# weighted avg       0.90      0.89      0.89        45
